# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# **To-Do:** *Replace this cell with your problem statement.*

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def mean_of_nums (nums):
    
    return sum(nums) / len(nums)

test_nums=[2,4,67,3,5]

mean_of_nums (test_nums)
# Out:
# 16.2

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:

def std_dev (nums):
    # get the mean of all the numbers
    col_mean = mean_of_nums (test_nums)
    
    # subtract that mean from each number and square the result
    new_list=[(num - col_mean) ** 2 for num in nums]
    
    # add everything up and divide by number of numbers -1
    # this is the variance
    var = sum(new_list) / (len(nums)-1)
    # sqr rt of variance is the standard deviation
    return round(var ** .5,2)

test_nums=[23,45,31,59,38,46,55,43,23,45,]

std_dev(test_nums)
# Out:
# 12.19

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def perc_to_float (num):
    
    return   float(num.replace('%','')) / 100
    
test_num1 = '50%'
test_num2 = '35%'
test_num3 = '74%'
          
perc_to_float (test_num1) , perc_to_float (test_num2)   , perc_to_float (test_num3)
# Out:
# (0.5, 0.35, 0.74)

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Code:
# create dataframes by importing the CSV data provided

df_act2017 = pd.read_csv('../data/act_2017.csv')
df_act2018 = pd.read_csv('../data/act_2018.csv')
df_act2019 = pd.read_csv('../data/act_2019.csv')
df_sat2017 = pd.read_csv('../data/sat_2017.csv')
df_sat2018 = pd.read_csv('../data/sat_2018.csv')
df_sat2019 = pd.read_csv('../data/sat_2019.csv')

# %%
# In some of the dataframes, scores are stored as strings.  This function takes the test score as input and returns the value as a float. In some of the dataframes, scores are stored strings

def clean_composite (score):
     return float(score)

# %%
# In some of the dataframes, participation is stored as a string.  This function takes the participation value as input and returns either a null value when one is missing, or removes the % from the string and converts the value to a float.  
def clean_participation (part):
    if part == '—':
        return np.nan
    else:
        return float(part.strip('%'))/100

# %%
# A quick check to make sure evything looks o.k
df_act2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
df_act2017.describe() 
# Why are there 52 values if this is supposed to be by state?
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
df_act2017.isnull().sum() 
# No nulls
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %%
df_act2017['State'].sort_values() 
# 'National' probably doesn't need to be in there since we're going to look at everything in a compsite way anyway.  DC maybe doesn't either since we're doing a state for state comp, but that means that there is a state missing? will look at the other data sets.
# Out:
# 1                  Alabama
# 2                   Alaska
# 3                  Arizona
# 4                 Arkansas
# 5               California
# 6                 Colorado
# 7              Connecticut
# 8                 Delaware
# 9     District of Columbia
# 10                 Florida
# 11                 Georgia
# 12                  Hawaii
# 13                   Idaho
# 14                Illinois
# 15                 Indiana
# 16                    Iowa
# 17                  Kansas
# 18                Kentucky
# 19               Louisiana
# 20                   Maine
# 21                Maryland
# 22           Massachusetts
# 23                Michigan
# 24               Minnesota
# 25             Mississippi
# 26                Missouri
# 27                 Montana
# 0                 National
# 28                Nebraska
# 29                  Nevada
# 30           New Hampshire
# 31              New Jersey
# 32              New Mexico
# 33                New York
# ...

# %%
df_act2017['Participation'].sort_values() 
# These values seem ok
# Out:
# 0      60%
# 45    100%
# 43    100%
# 41    100%
# 37    100%
# 34    100%
# 29    100%
# 27    100%
# 26    100%
# 50    100%
# 24    100%
# 19    100%
# 18    100%
# 25    100%
# 51    100%
# 4     100%
# 6     100%
# 1     100%
# 30     18%
# 8      18%
# 40     21%
# 39     23%
# 21     28%
# 48     29%
# 46     29%
# 23     29%
# 22     29%
# 47     29%
# 7      31%
# 33     31%
# 5      31%
# 9      32%
# 31     34%
# 15     35%
# 13     38%
# 38     40%
# 44     45%
# 11     55%
# 3      62%
# 2      65%
# 32     66%
# 16     67%
# 49     69%
# 10     73%
# 17     73%
# 36     75%
# 20      8%
# 42     80%
# 28     84%
# 12     90%
# 14     93%
# 35     98%
# Name: Participation, dtype: object

# %%
df_act2017['English'].sort_values()
# These values seem ok
# Out:
# 29    16.3
# 41    17.5
# 34    17.8
# 12    17.8
# 25    18.2
# 37    18.5
# 3     18.6
# 32    18.6
# 2     18.7
# 1     18.9
# 4     18.9
# 35    19.0
# 10    19.0
# 27    19.0
# 19    19.4
# 51    19.4
# 43    19.5
# 45    19.5
# 44    19.5
# 18    19.6
# 50    19.7
# 26    19.8
# 49    20.0
# 6     20.1
# 0     20.3
# 24    20.4
# 42    20.7
# 28    20.9
# 48    20.9
# 14    21.0
# 11    21.0
# 17    21.1
# 38    21.2
# 36    21.2
# 16    21.2
# 13    21.9
# 15    22.0
# 5     22.5
# 21    23.3
# 46    23.3
# 39    23.4
# 47    23.5
# 33    23.8
# 31    23.8
# 40    24.0
# 8     24.1
# 23    24.1
# 20    24.2
# 9     24.4
# 22    25.4
# 30    25.4
# 7     25.5
# Name: English, dtype: float64

# %%
df_act2017['Math'].sort_values()
# These values seem ok
# Out:
# 29    18.0
# 25    18.1
# 1     18.4
# 41    18.6
# 37    18.8
# 19    18.8
# 4     19.0
# 43    19.2
# 12    19.2
# 34    19.3
# 49    19.4
# 32    19.4
# 10    19.4
# 18    19.4
# 51    19.8
# 3     19.8
# 2     19.8
# 26    19.9
# 45    19.9
# 27    20.2
# 6     20.3
# 50    20.4
# 35    20.4
# 44    20.7
# 0     20.7
# 11    20.9
# 28    20.9
# 14    21.2
# 17    21.3
# 16    21.3
# 24    21.5
# 42    21.5
# 38    21.5
# 36    21.6
# 13    21.8
# 48    21.9
# 15    22.4
# 5     22.7
# 46    23.1
# 21    23.1
# 40    23.3
# 47    23.3
# 8     23.4
# 39    23.4
# 9     23.5
# 23    23.7
# 31    23.8
# 20    24.0
# 33    24.0
# 7     24.6
# 30    25.1
# 22    25.3
# Name: Math, dtype: float64

# %%
df_act2017['Reading'].sort_values()
# These values seem ok
# Out:
# 29    18.1
# 25    18.8
# 41    19.1
# 12    19.2
# 34    19.6
# 1     19.7
# 4     19.7
# 19    19.8
# 37    20.1
# 3     20.1
# 43    20.1
# 32    20.4
# 2     20.4
# 35    20.5
# 18    20.5
# 50    20.6
# 45    20.8
# 26    20.8
# 51    20.8
# 27    21.0
# 10    21.0
# 44    21.1
# 49    21.2
# 6     21.2
# 0     21.4
# 14    21.6
# 24    21.8
# 28    21.9
# 11    22.0
# 48    22.1
# 42    22.3
# 17    22.3
# 38    22.4
# 36    22.5
# 16    22.6
# 13    23.0
# 5     23.1
# 15    23.2
# 31    24.1
# 21    24.2
# 39    24.2
# 46    24.4
# 23    24.5
# 33    24.6
# 47    24.6
# 40    24.7
# 8     24.8
# 20    24.8
# 9     24.9
# 7     25.6
# 22    25.9
# 30    26.0
# Name: Reading, dtype: float64

# %%
df_act2017['Science'].sort_values()  
# notice the 2.3. We dont know what that value should be, probably best to remove it.
# Out:
# 21     2.3
# 29    18.2
# 25    18.8
# 41    18.9
# 34    19.3
# 12    19.3
# 10    19.4
# 1     19.4
# 4     19.5
# 37    19.6
# 19    19.6
# 3     19.8
# 43    19.9
# 2     19.9
# 32    20.0
# 18    20.1
# 49    20.5
# 27    20.5
# 26    20.5
# 45    20.6
# 35    20.6
# 51    20.6
# 50    20.9
# 6     20.9
# 44    20.9
# 0     21.0
# 14    21.3
# 11    21.3
# 28    21.5
# 24    21.6
# 17    21.7
# 38    21.7
# 48    22.0
# 42    22.0
# 36    22.0
# 13    22.1
# 16    22.1
# 5     22.2
# 15    22.3
# 31    23.2
# 46    23.2
# 39    23.3
# 40    23.4
# 9     23.5
# 47    23.5
# 8     23.6
# 20    23.7
# 23    23.8
# 33    23.9
# 7     24.6
# 22    24.7
# 30    24.9
# Name: Science, dtype: float64

# %%
df_act2017['Composite'].sort_values() 
# notice the 20.2x, maybe should be 20.2?
# Out:
# 29     17.8
# 25     18.6
# 41     18.7
# 12     19.0
# 34     19.1
# 1      19.2
# 4      19.4
# 37     19.4
# 19     19.5
# 3      19.7
# 32     19.7
# 2      19.8
# 43     19.8
# 10     19.8
# 18     20.0
# 51    20.2x
# 35     20.3
# 27     20.3
# 45     20.3
# 49     20.4
# 26     20.4
# 50     20.5
# 44     20.7
# 6      20.8
# 0      21.0
# 14     21.4
# 28     21.4
# 11     21.4
# 24     21.5
# 17     21.7
# 42     21.8
# 38     21.8
# 48     21.9
# 16     21.9
# 36     22.0
# 13     22.3
# 15     22.6
# 5      22.8
# 46     23.6
# 21     23.6
# 39     23.7
# 47     23.8
# 31     23.9
# 40     24.0
# 8      24.1
# 23     24.1
# 9      24.2
# 33     24.2
# 20     24.3
# 7      25.2
# 22     25.4
# 30     25.5
# Name: Composite, dtype: object

# %%
df_act2017.at[21,'Science'] # confirming location of 2.3 score in science
# Out:
# 2.3

# %%
df_act2017.at[21,'Science'] = np.nan # removing 2.3 score in science

# %%
df_act2017.at[21,'Science'] # confirming null value score in science
# Out:
# nan

# %%
df_act2017.dtypes # need to correct the 20.2x in Composite.  Checking the datatype first.  Object not float because of the 'x'
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
df_act2017.at[51,'Composite'] = '20.2'

# %%
df_act2017['Composite'] = df_act2017['Composite'].map(clean_composite)

# %%
df_act2017.dtypes # composite is now 'float'
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
df_act2017['Participation'] = df_act2017['Participation'].map(clean_participation)

# %%
df_act2017.dtypes  #fixed participation
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
df_act2017.columns = df_act2017.columns.str.lower()

# %%
df_act2017.head()
# Out:
#       state  participation  english  math  reading  science  composite
# 0  National           0.60     20.3  20.7     21.4     21.0       21.0
# 1   Alabama           1.00     18.9  18.4     19.7     19.4       19.2
# 2    Alaska           0.65     18.7  19.8     20.4     19.9       19.8
# 3   Arizona           0.62     18.6  19.8     20.1     19.8       19.7
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5       19.4

# %%
df_act2017['year'] = 2017
df_act2017.head()
# Out:
#       state  participation  english  math  reading  science  composite  year
# 0  National           0.60     20.3  20.7     21.4     21.0       21.0  2017
# 1   Alabama           1.00     18.9  18.4     19.7     19.4       19.2  2017
# 2    Alaska           0.65     18.7  19.8     20.4     19.9       19.8  2017
# 3   Arizona           0.62     18.6  19.8     20.1     19.8       19.7  2017
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5       19.4  2017

# %%
df_act2017[0:1] #comfirme national in [0]
# Out:
#       state  participation  english  math  reading  science  composite  year
# 0  National            0.6     20.3  20.7     21.4     21.0       21.0  2017

# %%
df_act2017 = df_act2017.drop(df_act2017.index[0])  #removed 'National', confirmed only 51 rows
df_act2017.describe()
# Out:
#        participation    english       math    reading    science  composite  \
# count      51.000000  51.000000  51.000000  51.000000  50.000000  51.000000
# mean        0.652549  20.931373  21.182353  22.013725  21.416000  21.519608
# std         0.321408   2.353677   1.981989   2.067271   1.738796   2.020695
# min         0.080000  16.300000  18.000000  18.100000  18.200000  17.800000
# 25%         0.310000  19.000000  19.400000  20.450000  19.925000  19.800000
# 50%         0.690000  20.700000  20.900000  21.800000  21.300000  21.400000
# 75%         1.000000  23.300000  23.100000  24.150000  22.975000  23.600000
# max         1.000000  25.500000  25.300000  26.000000  24.900000  25.500000
#
#          year
# count    51.0
# mean   2017.0
# std       0.0
# min    2017.0
# 25%    2017.0
# 50%    2017.0
# 75%    2017.0
# max    2017.0

# %%
#***************************************************************************************************************

# %%
df_act2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
df_act2018.describe() # 52 values?  Fewer columns than in 2017   Participation should be %
# Out:
#        Composite
# count  52.000000
# mean   21.544231
# std     2.119417
# min    17.700000
# 25%    19.975000
# 50%    21.300000
# 75%    23.725000
# max    25.600000

# %%
df_act2018.isnull().sum() # No nulls
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
df_act2018['State'].sort_values() # 'DC is there, that's fine.   Maine is listed twice. # DIstrict of columbia, needs capital 'C'
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                   Maine
# 21                Maryland
# 22           Massachusetts
# 23                Michigan
# 24               Minnesota
# 25             Mississippi
# 26                Missouri
# 27                 Montana
# 28                Nebraska
# 29                  Nevada
# 30           New Hampshire
# 31              New Jersey
# 32              New Mexico
# 33                New York
# ...

# %%
df_act2018['Participation'].sort_values()
# Out:
# 0     100%
# 45    100%
# 43    100%
# 41    100%
# 37    100%
# 36    100%
# 34    100%
# 29    100%
# 28    100%
# 27    100%
# 26    100%
# 50    100%
# 18    100%
# 17    100%
# 25    100%
# 51    100%
# 3     100%
# 40     15%
# 30     16%
# 7      17%
# 39     20%
# 23     22%
# 48     24%
# 47     24%
# 46     24%
# 22     25%
# 6      26%
# 4      27%
# 33     27%
# 5      30%
# 31     31%
# 21     31%
# 14     32%
# 8      32%
# 1      33%
# 12     36%
# 38     42%
# 13     43%
# 44     45%
# 10     53%
# 49     65%
# 9      66%
# 2      66%
# 32     67%
# 15     68%
# 19      7%
# 20      7%
# 16     71%
# 42     77%
# 11     89%
# 35     98%
# 24     99%
# Name: Participation, dtype: object

# %%
df_act2018['Composite'].sort_values()
# Out:
# 29    17.7
# 41    18.3
# 25    18.6
# 11    18.9
# 34    19.1
# 0     19.1
# 2     19.2
# 18    19.2
# 37    19.3
# 32    19.4
# 3     19.4
# 43    19.6
# 9     19.9
# 51    20.0
# 27    20.0
# 26    20.0
# 28    20.1
# 17    20.2
# 49    20.3
# 36    20.3
# 35    20.3
# 45    20.4
# 50    20.5
# 44    20.7
# 1     20.8
# 38    21.3
# 24    21.3
# 10    21.4
# 16    21.6
# 15    21.8
# 42    21.9
# 48    22.2
# 12    22.3
# 14    22.5
# 21    22.5
# 4     22.7
# 39    23.5
# 8     23.6
# 31    23.7
# 7     23.8
# 47    23.9
# 5     23.9
# 13    23.9
# 20    24.0
# 19    24.0
# 46    24.1
# 23    24.2
# 40    24.2
# 33    24.5
# 30    25.1
# 22    25.5
# 6     25.6
# Name: Composite, dtype: float64

# %%
df_act2018[19:21] # confirmed Maine is truly duplicate
# Out:
#     State Participation  Composite
# 19  Maine            7%       24.0
# 20  Maine            7%       24.0

# %%
df_act2018 = df_act2018.drop(df_act2018.index[19])  #removed 'Maine', confirmed only 51 rows
df_act2018.describe()
# Out:
#        Composite
# count  51.000000
# mean   21.496078
# std     2.111583
# min    17.700000
# 25%    19.950000
# 50%    21.300000
# 75%    23.650000
# max    25.600000

# %%
df_act2018.dtypes # need to fix participation
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
df_act2018['Participation'] = df_act2018['Participation'].map(clean_participation)
df_act2018.dtypes  #fixed participation
# Out:
# State             object
# Participation    float64
# Composite        float64
# dtype: object

# %%
df_act2018.columns = df_act2018.columns.str.lower() # fix column names
df_act2018.dtypes
# Out:
# state             object
# participation    float64
# composite        float64
# dtype: object

# %%
df_act2018['year'] = 2018
df_act2018.head()
# Out:
#         state  participation  composite  year
# 0     Alabama           1.00       19.1  2018
# 1      Alaska           0.33       20.8  2018
# 2     Arizona           0.66       19.2  2018
# 3    Arkansas           1.00       19.4  2018
# 4  California           0.27       22.7  2018

# %%
df_act2018[8:9] # confirm District of Columbia
# Out:
#                   state  participation  composite  year
# 8  District of columbia           0.32       23.6  2018

# %%
df_act2018.at[8,'state'] = 'District of Columbia'

# %%
df_act2018.describe()  # nothing more to clean for now, maybe remove the extra rows from 2017
# Out:
#        participation  composite    year
# count      51.000000  51.000000    51.0
# mean        0.617255  21.496078  2018.0
# std         0.340371   2.111583     0.0
# min         0.070000  17.700000  2018.0
# 25%         0.285000  19.950000  2018.0
# 50%         0.660000  21.300000  2018.0
# 75%         1.000000  23.650000  2018.0
# max         1.000000  25.600000  2018.0

# %%
#***************************************************************************************************************

# %%
df_act2019.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
df_act2019.describe() # 52 values?  Fewer columns than in 2017   Participation should be %
# Out:
#        Composite
# count  52.000000
# mean   21.450000
# std     2.175487
# min    17.900000
# 25%    19.800000
# 50%    20.950000
# 75%    23.650000
# max    25.500000

# %%
df_act2018.isnull().sum() # No nulls
# Out:
# state            0
# participation    0
# composite        0
# year             0
# dtype: int64

# %%
df_act2019['State'].sort_values() # 'DC is there, that's fine.  National needs to come out
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 51                National
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# ...

# %%
df_act2019['Participation'].sort_values()
# Out:
# 0     100%
# 36    100%
# 35    100%
# 33    100%
# 42    100%
# 28    100%
# 27    100%
# 26    100%
# 50    100%
# 24    100%
# 18    100%
# 17    100%
# 44    100%
# 3     100%
# 49    100%
# 39     12%
# 7      13%
# 29     14%
# 38     17%
# 22     19%
# 45     20%
# 21     21%
# 46     21%
# 32     22%
# 6      22%
# 4      23%
# 47     24%
# 30     25%
# 5      27%
# 20     28%
# 14     29%
# 12     31%
# 8      32%
# 13     35%
# 1      38%
# 43     39%
# 37     42%
# 10     49%
# 48     49%
# 51     52%
# 9      54%
# 19      6%
# 31     63%
# 15     66%
# 16     72%
# 2      73%
# 41     75%
# 40     78%
# 11     80%
# 25     82%
# 23     95%
# 34     96%
# Name: Participation, dtype: object

# %%
df_act2019['Composite'].sort_values()
# Out:
# 28    17.9
# 24    18.4
# 18    18.8
# 40    18.8
# 36    18.9
# 0     18.9
# 33    19.0
# 2     19.0
# 11    19.0
# 3     19.3
# 31    19.3
# 42    19.4
# 50    19.8
# 17    19.8
# 26    19.8
# 34    19.9
# 35    20.0
# 27    20.0
# 9     20.1
# 1     20.1
# 44    20.3
# 49    20.3
# 43    20.5
# 51    20.7
# 25    20.8
# 48    20.8
# 37    21.1
# 16    21.2
# 10    21.4
# 23    21.4
# 15    21.6
# 41    21.6
# 47    22.1
# 20    22.3
# 14    22.5
# 12    22.5
# 4     22.6
# 8     23.5
# 38    23.6
# 5     23.8
# 46    24.0
# 7     24.1
# 45    24.1
# 30    24.2
# 13    24.3
# 19    24.3
# 22    24.4
# 32    24.5
# 39    24.7
# 29    25.0
# 21    25.5
# 6     25.5
# Name: Composite, dtype: float64

# %%
df_act2019.dtypes  # need to fix participation
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
df_act2019['Participation'] = df_act2019['Participation'].map(clean_participation)
df_act2019.dtypes  #fixed participation
# Out:
# State             object
# Participation    float64
# Composite        float64
# dtype: object

# %%
df_act2019.columns = df_act2019.columns.str.lower() # fix column names

# %%
df_act2019['year'] = 2019
df_act2019.head()
# Out:
#         state  participation  composite  year
# 0     Alabama           1.00       18.9  2019
# 1      Alaska           0.38       20.1  2019
# 2     Arizona           0.73       19.0  2019
# 3    Arkansas           1.00       19.3  2019
# 4  California           0.23       22.6  2019

# %%
df_act2019[51:] #comfirme national in [51]
# Out:
#        state  participation  composite  year
# 51  National           0.52       20.7  2019

# %%
df_act2019 = df_act2019.drop(df_act2019.index[51])  #removed 'National', confirmed only 51 rows
df_act2019.describe()
# Out:
#        participation  composite    year
# count      51.000000  51.000000    51.0
# mean        0.586667  21.464706  2019.0
# std         0.345159   2.194523     0.0
# min         0.060000  17.900000  2019.0
# 25%         0.245000  19.800000  2019.0
# 50%         0.540000  21.100000  2019.0
# 75%         1.000000  23.700000  2019.0
# max         1.000000  25.500000  2019.0

# %%
#***************************************************************************************************************
# Confirm ACT 2017, 2018, 2019 looks right
#***************************************************************************************************************

# %%
df_act2017.head()
# Out:
#         state  participation  english  math  reading  science  composite  year
# 1     Alabama           1.00     18.9  18.4     19.7     19.4       19.2  2017
# 2      Alaska           0.65     18.7  19.8     20.4     19.9       19.8  2017
# 3     Arizona           0.62     18.6  19.8     20.1     19.8       19.7  2017
# 4    Arkansas           1.00     18.9  19.0     19.7     19.5       19.4  2017
# 5  California           0.31     22.5  22.7     23.1     22.2       22.8  2017

# %%
df_act2018.head()
# Out:
#         state  participation  composite  year
# 0     Alabama           1.00       19.1  2018
# 1      Alaska           0.33       20.8  2018
# 2     Arizona           0.66       19.2  2018
# 3    Arkansas           1.00       19.4  2018
# 4  California           0.27       22.7  2018

# %%
df_act2019.head()
# Out:
#         state  participation  composite  year
# 0     Alabama           1.00       18.9  2019
# 1      Alaska           0.38       20.1  2019
# 2     Arizona           0.73       19.0  2019
# 3    Arkansas           1.00       19.3  2019
# 4  California           0.23       22.6  2019

# %%
####  STEP 1 - 2017 SAT
df_sat2017.head()     # clean column names
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
df_sat2017.describe() # 51 values?    Math min of 52?  Where is participation?
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
####  STEP 2 - 2017 SAT
df_sat2017.isnull().sum()  # No nulls
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
####  STEP 3 - 2017 SAT
df_sat2017['State'].sort_values()   # DC is in there, thats ok
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
df_sat2017['Participation'].sort_values()   # Participation needs to be fixed
# Out:
# 26     10%
# 22    100%
# 6     100%
# 7     100%
# 8     100%
# 5      11%
# 31     11%
# 35     12%
# 48     14%
# 24      2%
# 15      2%
# 34      2%
# 28     26%
# 27      3%
# 23      3%
# 49      3%
# 41      3%
# 44      3%
# 25      3%
# 50      3%
# 3       3%
# 2      30%
# 1      38%
# 18      4%
# 17      4%
# 16      4%
# 37     43%
# 33     49%
# 0       5%
# 42      5%
# 40     50%
# 4      53%
# 11     55%
# 45     60%
# 10     61%
# 43     62%
# 14     63%
# 47     64%
# 46     65%
# 38     65%
# 32     67%
# 20     69%
# 36      7%
# 30     70%
# 39     71%
# 21     76%
# 9      83%
# 13      9%
# 12     93%
# 19     95%
# 29     96%
# Name: Participation, dtype: object

# %%
df_sat2017['Evidence-Based Reading and Writing'].sort_values()
# Out:
# 8     482
# 7     503
# 22    509
# 19    513
# 43    513
# 12    513
# 9     520
# 32    528
# 30    530
# 36    530
# 6     530
# 4     531
# 29    532
# 10    535
# 20    536
# 39    539
# 38    540
# 47    541
# 14    542
# 40    543
# 11    544
# 33    546
# 1     547
# 21    555
# 48    558
# 13    559
# 37    560
# 46    561
# 45    562
# 2     563
# 28    563
# 31    577
# 35    578
# 0     593
# 26    605
# 5     606
# 18    611
# 41    612
# 3     614
# 42    623
# 44    624
# 50    626
# 27    629
# 17    631
# 16    632
# 24    634
# 34    635
# 25    640
# 15    641
# 49    642
# 23    644
# Name: Evidence-Based Reading and Writing, dtype: int64

# %%
df_sat2017['Math'].sort_values()  # a score oc 52? probably needs to get removed, can't assue its 520, 502, 352 just too many possibilities
# Out:
# 20     52
# 8     468
# 7     492
# 12    493
# 22    495
# 9     497
# 19    499
# 43    507
# 6     512
# 10    515
# 36    517
# 29    520
# 40    521
# 32    523
# 39    524
# 4     524
# 30    526
# 48    528
# 38    531
# 14    532
# 1     533
# 47    534
# 33    535
# 46    541
# 11    541
# 37    548
# 21    551
# 45    551
# 2     553
# 28    553
# 13    556
# 31    561
# 35    570
# 0     572
# 18    586
# 26    591
# 3     594
# 5     595
# 41    603
# 42    604
# 50    604
# 24    607
# 44    614
# 17    616
# 34    621
# 27    625
# 16    628
# 25    631
# 15    635
# 49    649
# 23    651
# Name: Math, dtype: int64

# %%
df_sat2017['Total'].sort_values()
# Out:
# 8      950
# 7      996
# 12    1005
# 22    1005
# 19    1012
# 9     1017
# 43    1020
# 6     1041
# 36    1047
# 10    1050
# 32    1052
# 29    1052
# 4     1055
# 30    1056
# 20    1060
# 39    1062
# 40    1064
# 38    1071
# 14    1074
# 47    1075
# 1     1080
# 33    1081
# 11    1085
# 48    1086
# 46    1102
# 21    1107
# 37    1108
# 45    1114
# 13    1115
# 28    1116
# 2     1116
# 31    1138
# 35    1149
# 0     1165
# 26    1196
# 18    1198
# 5     1201
# 3     1208
# 41    1216
# 42    1228
# 50    1230
# 44    1238
# 24    1242
# 17    1247
# 27    1253
# 34    1256
# 16    1260
# 25    1271
# 15    1275
# 49    1291
# 23    1295
# Name: Total, dtype: int64

# %%
####  STEP 4 - 2017 SAT
df_sat2017.at[20,'Math'] # confirming 52 score in math
# Out:
# 52

# %%
df_sat2017[20:21]   # if we remove Maryland from SAT2017, then we'll have to remove it across the board because we can't run our statistics with NaN values.
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %%
df_sat2017 = df_sat2017.drop(df_sat2017.index[20]) # removing Maryland from SAT2017, will remove from larger combined later

# %%
df_sat2017.describe()   # confirming 52 score in math is gone
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                            50.00000   50.000000    50.000000
# mean                            569.78000  557.540000  1127.420000
# std                              45.88241   47.362781    92.945911
# min                             482.00000  468.000000   950.000000
# 25%                             532.75000  523.250000  1055.250000
# 50%                             559.50000  549.500000  1107.500000
# 75%                             613.50000  601.000000  1214.000000
# max                             644.00000  651.000000  1295.000000

# %%
####  STEP 5 - 2017 SAT
df_sat2017.dtypes  # need to fix participation
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
####  STEP 6 - 2017 SAT
df_sat2017['Participation'] = df_sat2017['Participation'].map(clean_participation)

# %%
df_sat2017.dtypes  #fixed participation
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
####  STEP 7 - 2017 SAT
df_sat2017.describe()
# Out:
#        Participation  Evidence-Based Reading and Writing        Math  \
# count      50.000000                            50.00000   50.000000
# mean        0.392200                           569.78000  557.540000
# std         0.353849                            45.88241   47.362781
# min         0.020000                           482.00000  468.000000
# 25%         0.040000                           532.75000  523.250000
# 50%         0.340000                           559.50000  549.500000
# 75%         0.650000                           613.50000  601.000000
# max         1.000000                           644.00000  651.000000
#
#              Total
# count    50.000000
# mean   1127.420000
# std      92.945911
# min     950.000000
# 25%    1055.250000
# 50%    1107.500000
# 75%    1214.000000
# max    1295.000000

# %%
df_sat2017.columns = df_sat2017.columns.str.lower() # fix column names

# %%
df_sat2017.rename(columns={'evidence-based reading and writing':'reading_writing'}, inplace=True) #shorten col names

# %%
df_sat2017.describe()
# Out:
#        sat_participation_17  sat_total_17
# count             50.000000     50.000000
# mean               0.392200   1127.420000
# std                0.353849     92.945911
# min                0.020000    950.000000
# 25%                0.040000   1055.250000
# 50%                0.340000   1107.500000
# 75%                0.650000   1214.000000
# max                1.000000   1295.000000

# %%
#### STEP 7 -  - 2017 SAT
df_sat2017['year'] = 2017

# %%
#### STEP 1 - 2018 SAT
df_sat2018.head(22)   # clean column names
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            6%                                 595
# 1                 Alaska           43%                                 562
# 2                Arizona           29%                                 577
# 3               Arkansas            5%                                 592
# 4             California           60%                                 540
# 5               Colorado          100%                                 519
# 6            Connecticut          100%                                 535
# 7               Delaware          100%                                 505
# 8   District of Columbia           92%                                 497
# 9                Florida           56%                                 550
# 10               Georgia           70%                                 542
# ...

# %%
df_sat2018.describe() # 51 values?    Where is participation?
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
#### STEP 2 - 2018 SAT
df_sat2018.isnull().sum()  # No nulls
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
#### STEP 3 - 2018 SAT
df_sat2018['State'].sort_values()   # DC is in there, thats ok
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
df_sat2018['Participation'].sort_values()   # Participation needs to be fixed
# Out:
# 26     10%
# 22    100%
# 12    100%
# 5     100%
# 6     100%
# 7     100%
# 31     16%
# 36     18%
# 34      2%
# 28     23%
# 48     28%
# 2      29%
# 27      3%
# 15      3%
# 49      3%
# 24      3%
# 41      3%
# 50      3%
# 23      4%
# 44      4%
# 25      4%
# 18      4%
# 17      4%
# 16      4%
# 1      43%
# 37     48%
# 3       5%
# 33     52%
# 40     55%
# 11     56%
# 9      56%
# 0       6%
# 42      6%
# 4      60%
# 14     63%
# 45     64%
# 43     66%
# 46     68%
# 47     69%
# 38     70%
# 10     70%
# 20     76%
# 32     79%
# 35      8%
# 21     80%
# 30     82%
# 8      92%
# 29     96%
# 39     97%
# 13     99%
# 19     99%
# Name: Participation, dtype: object

# %%
df_sat2018['Evidence-Based Reading and Writing'].sort_values()
# Out:
# 44    480
# 11    480
# 8     497
# 7     505
# 12    508
# 22    511
# 19    512
# 13    513
# 39    513
# 48    513
# 5     519
# 43    520
# 32    534
# 6     535
# 29    535
# 4     540
# 35    541
# 14    542
# 10    542
# 47    543
# 20    545
# 30    547
# 38    547
# 40    547
# 9     550
# 36    552
# 31    552
# 33    554
# 21    562
# 1     562
# 37    564
# 45    565
# 46    567
# 28    574
# 2     577
# 3     592
# 0     595
# 26    606
# 18    615
# 41    622
# 42    624
# 27    629
# 24    630
# 17    630
# 25    633
# 16    633
# 50    633
# 15    634
# 34    640
# 49    641
# 23    643
# Name: Evidence-Based Reading and Writing, dtype: int64

# %%
df_sat2018['Math'].sort_values()
# Out:
# 8     480
# 48    486
# 7     492
# 12    493
# 22    499
# 19    501
# 39    505
# 13    506
# 5     506
# 43    512
# 6     519
# 35    521
# 10    522
# 40    523
# 29    528
# 11    530
# 44    530
# 14    532
# 32    534
# 20    535
# 4     536
# 47    538
# 38    539
# 31    540
# 33    543
# 1     544
# 36    547
# 30    547
# 9     549
# 46    550
# 37    553
# 45    554
# 21    563
# 28    566
# 0     571
# 2     572
# 3     576
# 26    592
# 18    595
# 24    606
# 42    607
# 17    618
# 41    618
# 27    623
# 50    625
# 25    629
# 16    631
# 15    631
# 34    643
# 49    653
# 23    655
# Name: Math, dtype: int64

# %%
df_sat2018['Total'].sort_values()
# Out:
# 8      977
# 7      998
# 48     999
# 12    1001
# 44    1010
# 11    1010
# 22    1011
# 19    1013
# 39    1018
# 13    1019
# 5     1025
# 43    1032
# 6     1053
# 35    1062
# 29    1063
# 10    1064
# 32    1068
# 40    1070
# 14    1074
# 4     1076
# 20    1080
# 47    1081
# 38    1086
# 31    1093
# 30    1094
# 33    1098
# 9     1099
# 36    1099
# 1     1106
# 46    1117
# 37    1117
# 45    1120
# 21    1125
# 28    1140
# 2     1149
# 0     1166
# 3     1169
# 26    1198
# 18    1210
# 42    1231
# 24    1236
# 41    1240
# 17    1248
# 27    1252
# 50    1257
# 25    1262
# 16    1265
# 15    1265
# 34    1283
# 49    1294
# 23    1298
# Name: Total, dtype: int64

# %%
#### STEP 4 - 2018 SAT
# Nothing really to fix here

# %%
#### STEP 5 - 2018 SAT
df_sat2018.dtypes  # need to fix participation
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
#### STEP 6 - 2018 SAT
df_sat2018['Participation'] = df_sat2018['Participation'].map(clean_participation)

# %%
df_sat2018.dtypes  #fixed participation
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %%
#### STEP 7 - 2018 SAT
df_sat2018.describe()
# Out:
#        Participation  Evidence-Based Reading and Writing        Math  \
# count      51.000000                           51.000000   51.000000
# mean        0.457451                          563.686275  556.235294
# std         0.373143                           47.502627   47.772623
# min         0.020000                          480.000000  480.000000
# 25%         0.045000                          534.500000  522.500000
# 50%         0.520000                          552.000000  544.000000
# 75%         0.775000                          610.500000  593.500000
# max         1.000000                          643.000000  655.000000
#
#              Total
# count    51.000000
# mean   1120.019608
# std      94.155083
# min     977.000000
# 25%    1057.500000
# 50%    1098.000000
# 75%    1204.000000
# max    1298.000000

# %%
df_sat2018.columns = df_sat2018.columns.str.lower() # fix column names

# %%
df_sat2018.rename(columns={'evidence-based reading and writing':'reading_writing'}, inplace=True) #shorten col names

# %%
df_sat2018.describe()
# Out:
#        participation  reading_writing        math        total
# count      51.000000        51.000000   51.000000    51.000000
# mean        0.457451       563.686275  556.235294  1120.019608
# std         0.373143        47.502627   47.772623    94.155083
# min         0.020000       480.000000  480.000000   977.000000
# 25%         0.045000       534.500000  522.500000  1057.500000
# 50%         0.520000       552.000000  544.000000  1098.000000
# 75%         0.775000       610.500000  593.500000  1204.000000
# max         1.000000       643.000000  655.000000  1298.000000

# %%
df_sat2018['year'] = 2018

# %%
#### STEP 8 & 9 - 2018 SAT
df_sat2018.describe() #No other cleaning right now
# Out:
#        participation  reading_writing        math        total    year
# count      51.000000        51.000000   51.000000    51.000000    51.0
# mean        0.457451       563.686275  556.235294  1120.019608  2018.0
# std         0.373143        47.502627   47.772623    94.155083     0.0
# min         0.020000       480.000000  480.000000   977.000000  2018.0
# 25%         0.045000       534.500000  522.500000  1057.500000  2018.0
# 50%         0.520000       552.000000  544.000000  1098.000000  2018.0
# 75%         0.775000       610.500000  593.500000  1204.000000  2018.0
# max         1.000000       643.000000  655.000000  1298.000000  2018.0

# %%
#### STEP 1 - 2019 SAT

# %%
df_sat2019.head()   # clean column names  'Participation Rate'
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
df_sat2019.describe() # 53 values?    Math min of 52?  Where is participation?
# Out:
#              EBRW        Math        Total
# count   53.000000   53.000000    53.000000
# mean   558.000000  548.471698  1106.528302
# std     47.554422   53.785044   100.994784
# min    483.000000  445.000000   935.000000
# 25%    518.000000  506.000000  1024.000000
# 50%    550.000000  545.000000  1097.000000
# 75%    610.000000  596.000000  1200.000000
# max    636.000000  648.000000  1284.000000

# %%
#### STEP 2 - 2019 SAT
df_sat2019.isnull().sum()  # No nulls
# Out:
# State                 0
# Participation Rate    0
# EBRW                  0
# Math                  0
# Total                 0
# dtype: int64

# %%
#### STEP 3 - 2019 SAT
df_sat2019['State'].sort_values()   # DC is in there, thats ok    'Puerto Rico and Virgin Islands probably should come out
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
df_sat2019['Participation Rate'].sort_values()   # Participation needs to be fixed
# Out:
# 12    100%
# 22    100%
# 5     100%
# 6     100%
# 7     100%
# 40    100%
# 9     100%
# 13    100%
# 31     18%
# 35     19%
# 34      2%
# 28     20%
# 36     22%
# 51      3%
# 27      3%
# 52      3%
# 24      3%
# 42      3%
# 15      3%
# 2      31%
# 16      4%
# 17      4%
# 45      4%
# 23      4%
# 25      4%
# 1      41%
# 18      5%
# 33     51%
# 37     51%
# 11     54%
# 3       6%
# 4      63%
# 14     66%
# 46     66%
# 44     68%
# 41     68%
# 48     68%
# 43      7%
# 0       7%
# 49     70%
# 38     70%
# 10     71%
# 32     79%
# 21     81%
# 30     82%
# 20     82%
# 26      9%
# 8      94%
# 29     95%
# 19     99%
# 50     99%
# 39       —
# 47       —
# Name: Participation Rate, dtype: object

# %%
df_sat2019['EBRW'].sort_values()
# Out:
# 50    483
# 39    483
# 36    490
# 47    490
# 8     495
# 7     499
# 40    503
# 12    505
# 22    507
# 13    509
# 19    512
# 44    515
# 9     516
# 5     518
# 41    526
# 6     529
# 32    531
# 29    533
# 4     534
# 20    535
# 10    538
# 49    539
# 31    543
# 14    543
# 30    544
# 38    545
# 35    550
# 11    550
# 33    554
# 1     556
# 21    559
# 46    560
# 37    562
# 48    567
# 2     569
# 28    580
# 3     582
# 0     583
# 26    603
# 18    610
# 45    614
# 43    618
# 16    618
# 17    620
# 25    622
# 15    622
# 52    623
# 34    627
# 27    628
# 24    628
# 42    633
# 51    635
# 23    636
# Name: EBRW, dtype: int64

# %%
df_sat2019['Math'].sort_values()
# Out:
# 47    445
# 50    460
# 39    462
# 36    472
# 8     480
# 9     483
# 7     486
# 12    488
# 40    492
# 22    496
# 19    502
# 13    504
# 41    504
# 5     506
# 44    507
# 6     516
# 10    519
# 20    523
# 29    526
# 31    530
# 4     531
# 32    533
# 49    535
# 38    537
# 14    537
# 1     541
# 30    545
# 46    546
# 33    546
# 35    548
# 37    550
# 11    550
# 48    551
# 3     559
# 0     560
# 21    561
# 2     565
# 28    576
# 18    591
# 26    596
# 43    602
# 24    608
# 17    612
# 25    615
# 45    615
# 52    615
# 15    622
# 16    623
# 27    631
# 42    635
# 34    636
# 51    648
# 23    648
# Name: Math, dtype: int64

# %%
df_sat2019['Total'].sort_values()
# Out:
# 47     935
# 50     943
# 39     944
# 36     963
# 8      975
# 7      985
# 12     993
# 40     995
# 9      999
# 22    1003
# 13    1013
# 19    1013
# 44    1022
# 5     1024
# 41    1030
# 6     1046
# 10    1058
# 20    1058
# 29    1059
# 32    1064
# 4     1065
# 31    1073
# 49    1074
# 14    1080
# 38    1082
# 30    1090
# 1     1097
# 35    1097
# 33    1100
# 11    1100
# 46    1106
# 37    1112
# 48    1119
# 21    1120
# 2     1134
# 3     1141
# 0     1143
# 28    1156
# 26    1199
# 18    1200
# 43    1220
# 45    1230
# 17    1232
# 25    1236
# 24    1237
# 52    1238
# 16    1241
# 15    1244
# 27    1260
# 34    1263
# 42    1268
# 51    1283
# 23    1284
# Name: Total, dtype: int64

# %%
#### STEP 4 - 2019 SAT
df_sat2019[39:40] #comfirm Puerto Rico in [39]
# Out:
#           State Participation Rate  EBRW  Math  Total
# 39  Puerto Rico                  —   483   462    944

# %%
df_sat2019 = df_sat2019.drop(df_sat2019.index[39])  #removed 'PR', confirmed only 52 rows
df_sat2019.describe()
# Out:
#              EBRW        Math        Total
# count   52.000000   52.000000    52.000000
# mean   559.442308  550.134615  1109.653846
# std     46.833210   52.916149    99.358113
# min    483.000000  445.000000   935.000000
# 25%    524.000000  506.750000  1028.500000
# 50%    550.000000  545.500000  1097.000000
# 75%    611.000000  597.500000  1205.000000
# max    636.000000  648.000000  1284.000000

# %%
df_sat2019[44:48] #comfirm Virgin Islands in [47]
# Out:
#              State Participation Rate  EBRW  Math  Total
# 45            Utah                 4%   614   615   1230
# 46         Vermont                66%   560   546   1106
# 47  Virgin Islands                  —   490   445    935
# 48        Virginia                68%   567   551   1119

# %%
df_sat2019 = df_sat2019.drop(df_sat2019.index[46])  #removed 'VI', note the index changed since we droppped PR further up

# %%
df_sat2019[44:48]
# Out:
#          State Participation Rate  EBRW  Math  Total
# 45        Utah                 4%   614   615   1230
# 46     Vermont                66%   560   546   1106
# 48    Virginia                68%   567   551   1119
# 49  Washington                70%   539   535   1074

# %%
df_sat2019.describe()
# Out:
#              EBRW        Math        Total
# count   51.000000   51.000000    51.000000
# mean   560.803922  552.196078  1113.078431
# std     46.248035   51.290553    97.197910
# min    483.000000  460.000000   943.000000
# 25%    527.500000  511.500000  1038.000000
# 50%    550.000000  546.000000  1097.000000
# 75%    612.000000  599.000000  1210.000000
# max    636.000000  648.000000  1284.000000

# %%
df_sat2019['State'].sort_values()  #confirmed PR and VI are now gone
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
#### STEP 5 - 2019 SAT
df_sat2019.dtypes  # need to fix participation and column names
# Out:
# State                 object
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object

# %%
#### STEP 6 - 2019 SAT
df_sat2019['Participation Rate'] = df_sat2019['Participation Rate'].map(clean_participation)
df_sat2019.dtypes  #fixed participation
# Out:
# State                  object
# Participation Rate    float64
# EBRW                    int64
# Math                    int64
# Total                   int64
# dtype: object

# %%
#### STEP 7 - 2019 SAT
df_sat2019.describe()
# Out:
#        Participation Rate        EBRW        Math        Total
# count           51.000000   51.000000   51.000000    51.000000
# mean             0.490588  560.803922  552.196078  1113.078431
# std              0.387476   46.248035   51.290553    97.197910
# min              0.020000  483.000000  460.000000   943.000000
# 25%              0.055000  527.500000  511.500000  1038.000000
# 50%              0.540000  550.000000  546.000000  1097.000000
# 75%              0.820000  612.000000  599.000000  1210.000000
# max              1.000000  636.000000  648.000000  1284.000000

# %%
df_sat2019.columns = df_sat2019.columns.str.lower() # fix column names
df_sat2019.rename(columns={'participation rate':'participation'}, inplace=True) #shorten col names
df_sat2019.rename(columns={'ebrw':'reading_writing'}, inplace=True) #shorten col names

# %%
df_sat2019.describe()
# Out:
#        participation  reading_writing        math        total
# count      51.000000        51.000000   51.000000    51.000000
# mean        0.490588       560.803922  552.196078  1113.078431
# std         0.387476        46.248035   51.290553    97.197910
# min         0.020000       483.000000  460.000000   943.000000
# 25%         0.055000       527.500000  511.500000  1038.000000
# 50%         0.540000       550.000000  546.000000  1097.000000
# 75%         0.820000       612.000000  599.000000  1210.000000
# max         1.000000       636.000000  648.000000  1284.000000

# %%
df_sat2019['year'] = 2019

# %%
df_sat2019.describe()
# Out:
#        participation  reading_writing        math        total    year
# count      51.000000        51.000000   51.000000    51.000000    51.0
# mean        0.490588       560.803922  552.196078  1113.078431  2019.0
# std         0.387476        46.248035   51.290553    97.197910     0.0
# min         0.020000       483.000000  460.000000   943.000000  2019.0
# 25%         0.055000       527.500000  511.500000  1038.000000  2019.0
# 50%         0.540000       550.000000  546.000000  1097.000000  2019.0
# 75%         0.820000       612.000000  599.000000  1210.000000  2019.0
# max         1.000000       636.000000  648.000000  1284.000000  2019.0

# %%
df_act2017.head()  # can probably remove exptra columns
# Out:
#         state  participation  english  math  reading  science  composite  year
# 1     Alabama           1.00     18.9  18.4     19.7     19.4       19.2  2017
# 2      Alaska           0.65     18.7  19.8     20.4     19.9       19.8  2017
# 3     Arizona           0.62     18.6  19.8     20.1     19.8       19.7  2017
# 4    Arkansas           1.00     18.9  19.0     19.7     19.5       19.4  2017
# 5  California           0.31     22.5  22.7     23.1     22.2       22.8  2017

# %%
df_act2018.head()
# Out:
#         state  participation  composite  year
# 0     Alabama           1.00       19.1  2018
# 1      Alaska           0.33       20.8  2018
# 2     Arizona           0.66       19.2  2018
# 3    Arkansas           1.00       19.4  2018
# 4  California           0.27       22.7  2018

# %%
df_act2019.head()
# Out:
#         state  participation  composite  year
# 0     Alabama           1.00       18.9  2019
# 1      Alaska           0.38       20.1  2019
# 2     Arizona           0.73       19.0  2019
# 3    Arkansas           1.00       19.3  2019
# 4  California           0.23       22.6  2019

# %%
df_act2017.describe()
# Out:
#        participation    english       math    reading    science  composite  \
# count      51.000000  51.000000  51.000000  51.000000  50.000000  51.000000
# mean        0.652549  20.931373  21.182353  22.013725  21.416000  21.519608
# std         0.321408   2.353677   1.981989   2.067271   1.738796   2.020695
# min         0.080000  16.300000  18.000000  18.100000  18.200000  17.800000
# 25%         0.310000  19.000000  19.400000  20.450000  19.925000  19.800000
# 50%         0.690000  20.700000  20.900000  21.800000  21.300000  21.400000
# 75%         1.000000  23.300000  23.100000  24.150000  22.975000  23.600000
# max         1.000000  25.500000  25.300000  26.000000  24.900000  25.500000
#
#          year
# count    51.0
# mean   2017.0
# std       0.0
# min    2017.0
# 25%    2017.0
# 50%    2017.0
# 75%    2017.0
# max    2017.0

# %%
df_act2018.describe()
# Out:
#        participation  composite    year
# count      51.000000  51.000000    51.0
# mean        0.617255  21.496078  2018.0
# std         0.340371   2.111583     0.0
# min         0.070000  17.700000  2018.0
# 25%         0.285000  19.950000  2018.0
# 50%         0.660000  21.300000  2018.0
# 75%         1.000000  23.650000  2018.0
# max         1.000000  25.600000  2018.0

# %%
df_act2019.describe()
# Out:
#        participation  composite    year
# count      51.000000  51.000000    51.0
# mean        0.586667  21.464706  2019.0
# std         0.345159   2.194523     0.0
# min         0.060000  17.900000  2019.0
# 25%         0.245000  19.800000  2019.0
# 50%         0.540000  21.100000  2019.0
# 75%         1.000000  23.700000  2019.0
# max         1.000000  25.500000  2019.0

# %%
df_act2017.dtypes
# Out:
# state             object
# participation    float64
# english          float64
# math             float64
# reading          float64
# science          float64
# composite        float64
# year               int64
# dtype: object

# %%
df_act2017.drop(columns=['english','math','reading','science','year'], inplace=True)  # we dont have these for all tests and all years

# %%
df_act2017.rename(columns={'participation':'act_participation_17','composite':'act_composite_17'}, inplace=True) #better col names before merging data

# %%
df_act2017.dtypes
# Out:
# state                    object
# act_participation_17    float64
# act_composite_17        float64
# dtype: object

# %%
df_act2018.dtypes
# Out:
# state             object
# participation    float64
# composite        float64
# year               int64
# dtype: object

# %%
df_act2018.drop(columns=['year'], inplace=True)

# %%
df_act2018.rename(columns={'participation':'act_participation_18','composite':'act_composite_18'}, inplace=True) #better col names before merging data

# %%
df_act2018.dtypes
# Out:
# state                    object
# act_participation_18    float64
# act_composite_18        float64
# dtype: object

# %%
df_act2019.dtypes
# Out:
# state             object
# participation    float64
# composite        float64
# year               int64
# dtype: object

# %%
df_act2019.drop(columns=['year'], inplace=True)

# %%
df_act2019.rename(columns={'participation':'act_participation_19','composite':'act_composite_19'}, inplace=True) #better col names before merging data

# %%
df_act2019.dtypes
# Out:
# state                    object
# act_participation_19    float64
# act_composite_19        float64
# dtype: object

# %%
df_sat2017.head()
# Out:
#         state  participation  reading_writing  math  total  year
# 0     Alabama           0.05              593   572   1165  2017
# 1      Alaska           0.38              547   533   1080  2017
# 2     Arizona           0.30              563   553   1116  2017
# 3    Arkansas           0.03              614   594   1208  2017
# 4  California           0.53              531   524   1055  2017

# %%
df_sat2018.head()
# Out:
#         state  participation  reading_writing  math  total  year
# 0     Alabama           0.06              595   571   1166  2018
# 1      Alaska           0.43              562   544   1106  2018
# 2     Arizona           0.29              577   572   1149  2018
# 3    Arkansas           0.05              592   576   1169  2018
# 4  California           0.60              540   536   1076  2018

# %%
df_sat2019.head()
# Out:
#         state  participation  reading_writing  math  total  year
# 0     Alabama           0.07              583   560   1143  2019
# 1      Alaska           0.41              556   541   1097  2019
# 2     Arizona           0.31              569   565   1134  2019
# 3    Arkansas           0.06              582   559   1141  2019
# 4  California           0.63              534   531   1065  2019

# %%
df_sat2017.describe()
# Out:
#        participation  reading_writing        math        total    year
# count      50.000000         50.00000   50.000000    50.000000    50.0
# mean        0.392200        569.78000  557.540000  1127.420000  2017.0
# std         0.353849         45.88241   47.362781    92.945911     0.0
# min         0.020000        482.00000  468.000000   950.000000  2017.0
# 25%         0.040000        532.75000  523.250000  1055.250000  2017.0
# 50%         0.340000        559.50000  549.500000  1107.500000  2017.0
# 75%         0.650000        613.50000  601.000000  1214.000000  2017.0
# max         1.000000        644.00000  651.000000  1295.000000  2017.0

# %%
df_sat2018.describe()
# Out:
#        participation  reading_writing        math        total    year
# count      51.000000        51.000000   51.000000    51.000000    51.0
# mean        0.457451       563.686275  556.235294  1120.019608  2018.0
# std         0.373143        47.502627   47.772623    94.155083     0.0
# min         0.020000       480.000000  480.000000   977.000000  2018.0
# 25%         0.045000       534.500000  522.500000  1057.500000  2018.0
# 50%         0.520000       552.000000  544.000000  1098.000000  2018.0
# 75%         0.775000       610.500000  593.500000  1204.000000  2018.0
# max         1.000000       643.000000  655.000000  1298.000000  2018.0

# %%
df_sat2019.describe()
# Out:
#        participation  reading_writing        math        total    year
# count      51.000000        51.000000   51.000000    51.000000    51.0
# mean        0.490588       560.803922  552.196078  1113.078431  2019.0
# std         0.387476        46.248035   51.290553    97.197910     0.0
# min         0.020000       483.000000  460.000000   943.000000  2019.0
# 25%         0.055000       527.500000  511.500000  1038.000000  2019.0
# 50%         0.540000       550.000000  546.000000  1097.000000  2019.0
# 75%         0.820000       612.000000  599.000000  1210.000000  2019.0
# max         1.000000       636.000000  648.000000  1284.000000  2019.0

# %%
df_sat2017.dtypes
# Out:
# state               object
# participation      float64
# reading_writing      int64
# math                 int64
# total                int64
# year                 int64
# dtype: object

# %%
df_sat2017.drop(columns=['reading_writing','math','year'], inplace=True)
df_sat2017.rename(columns={'participation':'sat_participation_17','total':'sat_total_17'}, inplace=True) #better col names before merging data
df_sat2017.dtypes
# Out:
# state                    object
# sat_participation_17    float64
# sat_total_17              int64
# dtype: object

# %%
df_sat2018.dtypes
# Out:
# state               object
# participation      float64
# reading_writing      int64
# math                 int64
# total                int64
# year                 int64
# dtype: object

# %%
df_sat2018.drop(columns=['reading_writing','math','year'], inplace=True)
df_sat2018.rename(columns={'participation':'sat_participation_18','total':'sat_total_18'}, inplace=True) #better col names before merging data
df_sat2018.dtypes
# Out:
# state                    object
# sat_participation_18    float64
# sat_total_18              int64
# dtype: object

# %%
df_sat2019.dtypes
# Out:
# state               object
# participation      float64
# reading_writing      int64
# math                 int64
# total                int64
# year                 int64
# dtype: object

# %%
df_sat2019.drop(columns=['reading_writing','math','year'], inplace=True)
df_sat2019.rename(columns={'participation':'sat_participation_19','total':'sat_total_19'}, inplace=True) #better col names before merging data
df_sat2019.dtypes
# Out:
# state                    object
# sat_participation_19    float64
# sat_total_19              int64
# dtype: object

# %%
df_to_combine = [df_act2017, df_act2018, df_act2019, df_sat2017, df_sat2018, df_sat2019]

# %%
from functools import reduce
df_act_sat_combined = reduce(lambda  left,right: pd.merge(left,right,on=['state'],
                                            how='left'), df_to_combine)

# %%
df_act_sat_combined.head(22)  #notice the NaN at SAT2017, we have to remove Maryland
# Out:
#                    state  act_participation_17  act_composite_17  \
# 0                Alabama                  1.00              19.2
# 1                 Alaska                  0.65              19.8
# 2                Arizona                  0.62              19.7
# 3               Arkansas                  1.00              19.4
# 4             California                  0.31              22.8
# 5               Colorado                  1.00              20.8
# 6            Connecticut                  0.31              25.2
# 7               Delaware                  0.18              24.1
# 8   District of Columbia                  0.32              24.2
# 9                Florida                  0.73              19.8
# 10               Georgia                  0.55              21.4
# 11                Hawaii                  0.90              19.0
# 12                 Idaho                  0.38              22.3
# ...

# %%
df_act_sat_combined = df_act_sat_combined.drop(df_act_sat_combined.index[20])

# %%
df_act_sat_combined.head(22)  #confirming we removed Maryland
# Out:
#                    state  act_participation_17  act_composite_17  \
# 0                Alabama                  1.00              19.2
# 1                 Alaska                  0.65              19.8
# 2                Arizona                  0.62              19.7
# 3               Arkansas                  1.00              19.4
# 4             California                  0.31              22.8
# 5               Colorado                  1.00              20.8
# 6            Connecticut                  0.31              25.2
# 7               Delaware                  0.18              24.1
# 8   District of Columbia                  0.32              24.2
# 9                Florida                  0.73              19.8
# 10               Georgia                  0.55              21.4
# 11                Hawaii                  0.90              19.0
# 12                 Idaho                  0.38              22.3
# ...

# %%
df_act_sat_combined.dtypes
# Out:
# state                    object
# act_participation_17    float64
# act_composite_17        float64
# act_participation_18    float64
# act_composite_18        float64
# act_participation_19    float64
# act_composite_19        float64
# sat_participation_17    float64
# sat_total_17            float64
# sat_participation_18    float64
# sat_total_18              int64
# sat_participation_19    float64
# sat_total_19              int64
# dtype: object

# %%
df_act_sat_combined.describe()
# Out:
#        act_participation_17  act_composite_17  act_participation_18  \
# count             50.000000         50.000000             50.000000
# mean               0.660000         21.478000              0.623400
# std                0.320191          2.019021              0.340957
# min                0.080000         17.800000              0.070000
# 25%                0.312500         19.800000              0.277500
# 50%                0.710000         21.400000              0.660000
# 75%                1.000000         23.400000              1.000000
# max                1.000000         25.500000              1.000000
#
#        act_composite_18  act_participation_19  act_composite_19  \
# count         50.000000             50.000000         50.000000
# mean          21.476000              0.592800         21.448000
# std            2.128098              0.345844          2.213524
# min           17.700000              0.060000         17.900000
# ...

# %%
df_act_sat_combined.isnull().sum()
# Out:
# state                   0
# act_participation_17    0
# act_composite_17        0
# act_participation_18    0
# act_composite_18        0
# act_participation_19    0
# act_composite_19        0
# sat_participation_17    0
# sat_total_17            0
# sat_participation_18    0
# sat_total_18            0
# sat_participation_19    0
# sat_total_19            0
# dtype: int64

# %%
df_act_sat_combined.to_csv('../data/act_sat_combined.csv')

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|ACT/SAT Combined| State in which the exam were given
# |act_participation_17|float|ACT/SAT Combined|% of student who too the ACT in 2017
# |act_composite_17|float|ACT/SAT Combined|Average score for ACT exams administered in 2017
# |act_participation_18|float|ACT/SAT Combined|% of student who too the ACT in 2018
# |act_composite_18|float|ACT/SAT Combined|Average score for ACT exams administered in 2018
# |act_participation_19|float|ACT/SAT Combined|% of student who too the ACT in 2019
# |act_composite_19|float|ACT/SAT Combined|Average score for ACT exams administered in 2019
# |sat_participation_17|float|ACT/SAT Combined|% of student who too the SAT in 2017
# |sat_total_17|float|ACT/SAT Combined|Average score for SAT exams administered in 2017
# |sat_participation_18|float|ACT/SAT Combined|% of student who too the SAT in 2018
# |sat_total_18|int|ACT/SAT Combined|Average score for SAT exams administered in 2018
# |sat_participation_19|float|ACT/SAT Combined|% of student who too the SAT in 2019
# |sat_total_19|float|ACT/SAT Combined|Average score for SAT exams administered in 2019

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Code:
#Summary Statistics
df_act_sat_combined.head(5)
# Out:
#         state  act_participation_17  act_composite_17  act_participation_18  \
# 0     Alabama                  1.00              19.2                  1.00
# 1      Alaska                  0.65              19.8                  0.33
# 2     Arizona                  0.62              19.7                  0.66
# 3    Arkansas                  1.00              19.4                  1.00
# 4  California                  0.31              22.8                  0.27
#
#    act_composite_18  act_participation_19  act_composite_19  \
# 0              19.1                  1.00              18.9
# 1              20.8                  0.38              20.1
# 2              19.2                  0.73              19.0
# 3              19.4                  1.00              19.3
# 4              22.7                  0.23              22.6
#
#    sat_participation_17  sat_total_17  sat_participation_18  sat_total_18  \
# ...

# %%
df_act_sat_combined.shape  # 50 rows, 13 columns
# Out:
# (50, 13)

# %%
# No missing values
df_act_sat_combined.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 50
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   state                 50 non-null     object
#  1   act_participation_17  50 non-null     float64
#  2   act_composite_17      50 non-null     float64
#  3   act_participation_18  50 non-null     float64
#  4   act_composite_18      50 non-null     float64
#  5   act_participation_19  50 non-null     float64
#  6   act_composite_19      50 non-null     float64
#  7   sat_participation_17  50 non-null     float64
#  8   sat_total_17          50 non-null     float64
#  9   sat_participation_18  50 non-null     float64
#  10  sat_total_18          50 non-null     int64
#  11  sat_participation_19  50 non-null     float64
#  12  sat_total_19          50 non-null     int64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 5.5+ KB

# %%
df_act_sat_combined.describe()
# Out:
#        act_participation_17  act_composite_17  act_participation_18  \
# count             50.000000         50.000000             50.000000
# mean               0.660000         21.478000              0.623400
# std                0.320191          2.019021              0.340957
# min                0.080000         17.800000              0.070000
# 25%                0.312500         19.800000              0.277500
# 50%                0.710000         21.400000              0.660000
# 75%                1.000000         23.400000              1.000000
# max                1.000000         25.500000              1.000000
#
#        act_composite_18  act_participation_19  act_composite_19  \
# count         50.000000             50.000000         50.000000
# mean          21.476000              0.592800         21.448000
# std            2.128098              0.345844          2.213524
# min           17.700000              0.060000         17.900000
# ...

# %%
sd = [{std_dev(df_act_sat_combined[column]), column} for column in df_act_sat_combined.columns if df_act_sat_combined[column].dtype != 'O']

# %%
sd
# Out:
# [{40.55, 'act_participation_17'},
#  {19.62, 'act_composite_17'},
#  {40.59, 'act_participation_18'},
#  {19.64, 'act_composite_18'},
#  {40.62, 'act_participation_19'},
#  {19.67, 'act_composite_19'},
#  {40.82, 'sat_participation_17'},
#  {1101.58, 'sat_total_17'},
#  {40.76, 'sat_participation_18'},
#  {1095.11, 'sat_total_18'},
#  {40.73, 'sat_participation_19'},
#  {1088.68, 'sat_total_19'}]

# %%
# states with lowest ACT participation in 2017
df_act_sat_combined[['state','act_participation_17','act_composite_17']].sort_values('act_participation_17').head(5)
# Out:
#             state  act_participation_17  act_composite_17
# 19          Maine                  0.08              24.3
# 29  New Hampshire                  0.18              25.5
# 7        Delaware                  0.18              24.1
# 39   Rhode Island                  0.21              24.0
# 38   Pennsylvania                  0.23              23.7

# %% [markdown]
# ## States w/ Lowest ACT participation in 2017 and Average Scores
#
# |#|State|% Participation|Score|
# |---|---|---|---|
# 1.|Maine|8%|24.3
# 2.|New Hampshire|18%|25.5
# 3.|Delaware|18%|24.1
# 3.|Rhode Island|21%|24.0
# 3.|Pennsylvania|23%|23.7
#
# *Sorted by Participation, lowest to Highest
#
# **Note: These scores are all higher than those from any state with 100% Participation (see below)

# %%
# states with 100% ACT participation in 2017 (17 w/ 100% participation)
df_act_sat_combined[df_act_sat_combined['act_participation_17']==1].sort_values(['act_participation_17', 'act_composite_17'],ascending=False).head(19)[['state','act_participation_17','act_composite_17']]
# Out:
#              state  act_participation_17  act_composite_17
# 23       Minnesota                   1.0              21.5
# 5         Colorado                   1.0              20.8
# 49       Wisconsin                   1.0              20.5
# 25        Missouri                   1.0              20.4
# 26         Montana                   1.0              20.3
# 44            Utah                   1.0              20.3
# 50         Wyoming                   1.0              20.2
# 17        Kentucky                   1.0              20.0
# 42       Tennessee                   1.0              19.8
# 18       Louisiana                   1.0              19.5
# 3         Arkansas                   1.0              19.4
# 36        Oklahoma                   1.0              19.4
# 0          Alabama                   1.0              19.2
# 33  North Carolina                   1.0              19.1
# 40  South Carolina                   1.0              18.7
# ...

# %% [markdown]
# ## States w/ 100% ACT participation in 2017 and Average Scores
#
# |State|% Participation|Score|
# |---|---|---|
# |Minnesota|100%|21.5|
# |Colorado|100%|20.8|
# |Wisconsin|100%|20.5|
# |Missouri|100%|20.4|
# |Montana|100%|20.3|
# |Utah|100%|20.3|
# |Wyoming|100%|20.2|
# |Kentucky|100%|20.0|
# |Tennessee|100%|19.8|
# |Louisiana|100%|19.5|
# |Arkansas|100%|19.4|
# |Oklahoma|100%|19.4|
# |Alabama|100%|19.2|
# |North Carolina|100%|19.1|
# |South Carolina|100%|18.7|
# |Mississippi|100%|18.6|
# |Nevada|100%|17.8|
#
# *Sorted by Scores, Highest to Lowest
#
# **Note: These scores are all lower than those from the states with the lowest Participation (see above)

# %%
# states with lowest ACT participation in 2018
df_act_sat_combined[['state','act_participation_18','act_composite_18']].sort_values('act_participation_18').head(5)
# Out:
#             state  act_participation_18  act_composite_18
# 19          Maine                  0.07              24.0
# 39   Rhode Island                  0.15              24.2
# 29  New Hampshire                  0.16              25.1
# 7        Delaware                  0.17              23.8
# 38   Pennsylvania                  0.20              23.5

# %% [markdown]
# ## States w/ Lowest ACT participation in 2018 and Average Scores
#
# |#|State|% Participation|Score|
# |---|---|---|---|
# 1.|Maine|7%|24.0
# 2.|Rhode Island|15%|24.2
# 3.|New Hampshire|16%|25.1
# 3.|Delaware|17%|23.8
# 3.|Pennsylvania|20%|23.5
#
# *Sorted by Participation, Lowest to Highest
#
# **Note: These scores are all higher than those from any state with 100% Participation (see below)

# %%
# states with highest ACT participation in 2018 (17 w/ 100% participation)
df_act_sat_combined[df_act_sat_combined['act_participation_18']==1].sort_values(['act_participation_18', 'act_composite_18'],ascending=False).head(25)[['state','act_participation_18','act_composite_18']]
# Out:
#              state  act_participation_18  act_composite_18
# 49       Wisconsin                   1.0              20.5
# 44            Utah                   1.0              20.4
# 35            Ohio                   1.0              20.3
# 17        Kentucky                   1.0              20.2
# 27        Nebraska                   1.0              20.1
# 25        Missouri                   1.0              20.0
# 26         Montana                   1.0              20.0
# 50         Wyoming                   1.0              20.0
# 42       Tennessee                   1.0              19.6
# 3         Arkansas                   1.0              19.4
# 36        Oklahoma                   1.0              19.3
# 18       Louisiana                   1.0              19.2
# 0          Alabama                   1.0              19.1
# 33  North Carolina                   1.0              19.1
# 24     Mississippi                   1.0              18.6
# ...

# %% [markdown]
# ## States w/ 100% ACT participation in 2018 and Average Scores
#
# |State|% Participation|Score|
# |---|---|---|
# |Wisconsin|100%|20.5
# |Utah|100%|20.4
# |Ohio|100%|20.3
# |Kentucky|100%|20.2
# |Nebraska|100%|20.1
# |Missouri|100%|20.0
# |Montana|100%|20.0
# |Wyoming|100%|20.0
# |Tennessee|100%|19.6
# |Arkansas|100%|19.4
# |Oklahoma|100%|19.3
# |Louisiana|100%|19.2
# |Alabama|100%|19.1
# |North Carolina|100%|19.1
# |Mississippi|100%|18.6
# |South Carolina|100%|18.3
# |Nevada|100%|17.7
#
# *Sorted by Scores, Highest to Lowest
#
# **Note: These scores are all lower than those from the states with the lowest Participation (see above)

# %%
# states with lowest ACT participation in 2019
df_act_sat_combined[['state','act_participation_19','act_composite_19']].sort_values('act_participation_19').head(5)
# Out:
#             state  act_participation_19  act_composite_19
# 19          Maine                  0.06              24.3
# 39   Rhode Island                  0.12              24.7
# 7        Delaware                  0.13              24.1
# 29  New Hampshire                  0.14              25.0
# 38   Pennsylvania                  0.17              23.6

# %% [markdown]
# ## States w/ Lowest ACT participation in 2019 and Average Scores
#
# |#|State|% Participation|Score|
# |---|---|---|---|
# 1.|Maine|6%|24.3
# 2.|Rhode Island|12%|24.7
# 3.|Delaware|13%|24.1
# 3.|New Hampshire|14%|25.0
# 3.|Pennsylvania|17%|23.6
#
# *Sorted by Participation, Lowest to Highest
#
# **Note: These scores are all higher than those from any state with 100% Participation (see below)

# %%
# states with highest ACT participation in 2019 (16 w/ 100% participation)
df_act_sat_combined[df_act_sat_combined['act_participation_19']==1].sort_values(['act_participation_19', 'act_composite_19'],ascending=False).head(25)[['state','act_participation_19','act_composite_19']]
# Out:
#              state  act_participation_19  act_composite_19
# 44            Utah                   1.0              20.3
# 49       Wisconsin                   1.0              20.3
# 27        Nebraska                   1.0              20.0
# 35            Ohio                   1.0              20.0
# 17        Kentucky                   1.0              19.8
# 26         Montana                   1.0              19.8
# 50         Wyoming                   1.0              19.8
# 42       Tennessee                   1.0              19.4
# 3         Arkansas                   1.0              19.3
# 33  North Carolina                   1.0              19.0
# 0          Alabama                   1.0              18.9
# 36        Oklahoma                   1.0              18.9
# 18       Louisiana                   1.0              18.8
# 24     Mississippi                   1.0              18.4
# 28          Nevada                   1.0              17.9

# %% [markdown]
# ## States w/ 100% ACT participation in 2019 and Average Scores
#
# |State|% Participation|Score|
# |---|---|---|
# |Utah|100%|20.3
# |Wisconsin|100%|20.3
# |Nebraska|100%|20.0
# |Ohio|100%|20.0
# |Kentucky|100%|19.8
# |Montana|100%|19.8
# |Wyoming|100%|19.8
# |Tennessee|100%|19.4
# |Arkansas|100%|19.3
# |North Carolina|100%|19.0
# |Alabama|100%|18.9
# |Oklahoma|100%|18.9
# |Louisiana|100%|18.8
# |Mississippi|100%|18.4
# |Nevada|100%|17.9
#
# *Sorted by Scores, Highest to Lowest
#
# **Note: These scores are all lower than those from the states with the lowest Participation (see above)

# %%
# states with lowest SAT participation in 2017
df_act_sat_combined[['state','sat_participation_17','sat_total_17']].sort_values('sat_participation_17').head(5)
# Out:
#            state  sat_participation_17  sat_total_17
# 34  North Dakota                  0.02        1256.0
# 24   Mississippi                  0.02        1242.0
# 15          Iowa                  0.02        1275.0
# 25      Missouri                  0.03        1271.0
# 44          Utah                  0.03        1238.0

# %% [markdown]
# ## States w/ Lowest SAT participation in 2017 and Average Scores
#
# |#|State|% Participation|Score|
# |---|---|---|---|
# 1.|North Dakota|2%|1256
# 2.|Mississippi|2%|1242
# 3.|Iowa|2%|1275
# 3.|Missouri|3%|1271
# 3.|Utah|3%|1238.
#
# *Sorted by Participation, lowest to Highest
#
# **Note: These scores are all higher than those from any state with 100% Participation (see below)

# %%
# states with 100% SAT participation in 2017 (4 w/ 100% participation)
df_act_sat_combined[df_act_sat_combined['sat_participation_17']==1].sort_values(['sat_participation_17', 'sat_total_17'],ascending=False).head(19)[['state','sat_participation_17','sat_total_17']]
# Out:
#                    state  sat_participation_17  sat_total_17
# 6            Connecticut                   1.0        1041.0
# 22              Michigan                   1.0        1005.0
# 7               Delaware                   1.0         996.0
# 8   District of Columbia                   1.0         950.0

# %% [markdown]
# ## States w/ 100% SAT participation in 2017 and Average Scores
#
# |State|% Participation|Score|
# |---|---|---|
# |Connecticut|100%|1041
# |Michigan|100%|1005
# |Delaware|100%|996
# |District of Columbia|100%|950
#
#
# *Sorted by Scores, Highest to Lowest
#
# **Note: These scores are all lower than those from the states with the lowest Participation (see above)

# %%
# states with lowest SAT participation in 2018
df_act_sat_combined[['state','sat_participation_18','sat_total_18']].sort_values('sat_participation_18').head(5)
# Out:
#            state  sat_participation_18  sat_total_18
# 34  North Dakota                  0.02          1283
# 50       Wyoming                  0.03          1257
# 41  South Dakota                  0.03          1240
# 27      Nebraska                  0.03          1252
# 49     Wisconsin                  0.03          1294

# %% [markdown]
# ## States w/ Lowest SAT participation in 2018 and Average Scores
#
# |#|State|% Participation|Score|
# |---|---|---|---|
# 1.|North Dakota|2%|1283
# 2.|Wyoming|3%|1257
# 3.|South Dakota|3%|1240
# 3.|Nebraska|3%|1252
# 3.|Wisconsin|3%|1294
#
# *Sorted by Participation, lowest to Highest
#
# **Note: These scores are all higher than those from any state with 100% Participation (see below)

# %%
# states with 100% SAT participation in 2018 (5 w/ 100% participation)
df_act_sat_combined[df_act_sat_combined['sat_participation_18']==1].sort_values(['sat_participation_18', 'sat_total_18'],ascending=False).head(19)[['state','sat_participation_18','sat_total_18']]
# Out:
#           state  sat_participation_18  sat_total_18
# 6   Connecticut                   1.0          1053
# 5      Colorado                   1.0          1025
# 22     Michigan                   1.0          1011
# 12        Idaho                   1.0          1001
# 7      Delaware                   1.0           998

# %% [markdown]
# ## States w/ 100% SAT participation in 2018 and Average Scores
#
# |State|% Participation|Score|
# |---|---|---|
# |Connecticut|100%|1053
# |Colorado|100%|1025
# |Michigan|100%|1011
# |Idaho|100%|1001
# |Delaware|100%|998
#
# *Sorted by Scores, Highest to Lowest
#
# **Note: These scores are all lower than those from the states with the lowest Participation (see above)

# %%
# states with lowest SAT participation in 2019
df_act_sat_combined[['state','sat_participation_19','sat_total_19']].sort_values('sat_participation_19').head(5)
# Out:
#            state  sat_participation_19  sat_total_19
# 34  North Dakota                  0.02          1263
# 50       Wyoming                  0.03          1238
# 41  South Dakota                  0.03          1268
# 27      Nebraska                  0.03          1260
# 49     Wisconsin                  0.03          1283

# %% [markdown]
# ## States w/ Lowest SAT participation in 2019 and Average Scores
#
# |#|State|% Participation|Score|
# |---|---|---|---|
# 1.|North Dakota|2%|1263
# 2.|Wyoming|3%|1238
# 3.|South Dakota|3%|1268
# 3.|Nebraska|3%|1260
# 3.|Wisconsin|3%|1283
#
# *Sorted by Participation, lowest to Highest
#
# **Note: These scores are all higher than those from any state with 100% Participation (see below)

# %%
# states with 100% SAT participation in 2019 (8 w/ 100% participation)
df_act_sat_combined[df_act_sat_combined['sat_participation_19']==1].sort_values(['sat_participation_19', 'sat_total_19'],ascending=False).head(19)[['state','sat_participation_19','sat_total_19']]
# Out:
#            state  sat_participation_19  sat_total_19
# 6    Connecticut                   1.0          1046
# 5       Colorado                   1.0          1024
# 13      Illinois                   1.0          1013
# 22      Michigan                   1.0          1003
# 9        Florida                   1.0           999
# 39  Rhode Island                   1.0           995
# 12         Idaho                   1.0           993
# 7       Delaware                   1.0           985

# %% [markdown]
# ## States w/ 100% SAT participation in 2019 and Average Scores
#
# |State|% Participation|Score|
# |---|---|---|
# |Connecticut|100%|1046
# |Colorado|100%|1024
# |Illinois|100%|1013
# |Michigan|100%|1003
# |Florida|100%|999
# |Rhode Island|100%|995
# |Idaho|100%|993
# |Delaware|100%|985
#
# *Sorted by Scores, Highest to Lowest
#
# **Note: These scores are all lower than those from the states with the lowest Participation (see above)

# %% [markdown]
# **Findings:** *There appears to be an inverse relationship between participation and the mean score per state for both the ACT and SAT.  We see this across all three years worth of data.*

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# Code

# %%
# It looks like states with higher rate of participation actually have lower scores....
high_part = df_act_sat_combined[df_act_sat_combined['act_participation_17'] >= .7]

low_part = df_act_sat_combined[df_act_sat_combined['act_participation_17'] < .3]
plt.subplots(figsize=(10,8))
plt.hist(high_part['act_composite_17'],color='r',alpha=.5,label="High Particpiation");
plt.hist(low_part['act_composite_17'],color='b',alpha=.5,label="Low Participation");

plt.title('2017 ACT Scores for High / Low Participation',fontsize=20)
plt.figtext(.5, 0.01," Interpretation: The above image shows a side by side comparison of test scores for states with both high and low level of ACT participation in 2017. \n *High participation >= 70% / Low participation < 30%", wrap=True,verticalalignment='center_baseline', horizontalalignment='center', fontsize=12)
plt.legend();
plt.savefig("../images/2017_ACT_High_Low_hist.png")

# %%
# It looks like states with higher rate of participation actually have lower scores....
high_part = df_act_sat_combined[df_act_sat_combined['sat_participation_17'] >= .7]

low_part = df_act_sat_combined[df_act_sat_combined['sat_participation_17'] < .3]
plt.subplots(figsize=(10,8))
plt.hist(high_part['sat_total_17'],color='y',alpha=.5,label="High Particpiation");
plt.hist(low_part['sat_total_17'],color='g',alpha=.5,label="Low Participation");

plt.title('2017 SAT Scores for High / Low Participation',fontsize=20)
plt.figtext(.5, 0.01," Interpretation: The above image shows a side by side comparison of test scores for states with both high and low level of SAT participation in 2017. \n *High participation >= 70% / Low participation < 30%", wrap=True,verticalalignment='center_baseline', horizontalalignment='center', fontsize=12)
plt.legend();
plt.savefig("../images/2017_SAT_High_Low_hist.png")

# %%
# It looks like states with higher rate of participation actually have lower scores....
high_part = df_act_sat_combined[df_act_sat_combined['act_participation_18'] >= .7]

low_part = df_act_sat_combined[df_act_sat_combined['act_participation_18'] < .3]
plt.subplots(figsize=(10,8))
plt.hist(high_part['act_composite_18'],color='r',alpha=.5,label="High Particpiation");
plt.hist(low_part['act_composite_18'],color='b',alpha=.5,label="Low Participation");

plt.title('2018 ACT Scores for High / Low Participation',fontsize=20)
plt.figtext(.5, 0.01," Interpretation: The above image shows a side by side comparison of test scores for states with both high and low level of ACT participation in 2018. \n *High participation >= 70% / Low participation < 30%", wrap=True,verticalalignment='center_baseline', horizontalalignment='center', fontsize=12)
plt.legend();
plt.savefig("../images/2018_ACT_High_Low_hist.png")

# %%
# It looks like states with higher rate of participation actually have lower scores....
high_part = df_act_sat_combined[df_act_sat_combined['sat_participation_18'] >= .7]

low_part = df_act_sat_combined[df_act_sat_combined['sat_participation_18'] < .3]
plt.subplots(figsize=(10,8))
plt.hist(high_part['sat_total_18'],color='y',alpha=.5,label="High Particpiation");
plt.hist(low_part['sat_total_18'],color='g',alpha=.5,label="Low Participation");

plt.title('2018 SAT Scores for High / Low Participation',fontsize=20)
plt.figtext(.5, 0.01," Interpretation: The above image shows a side by side comparison of test scores for states with both high and low level of SAT participation in 2018. \n *High participation >= 70% / Low participation < 30%", wrap=True,verticalalignment='center_baseline', horizontalalignment='center', fontsize=12)
plt.legend();
plt.savefig("../images/2018_SAT_High_Low_hist.png")

# %%
# It looks like states with higher rate of participation actually have lower scores....
high_part = df_act_sat_combined[df_act_sat_combined['act_participation_19'] >= .7]

low_part = df_act_sat_combined[df_act_sat_combined['act_participation_19'] < .3]
plt.subplots(figsize=(10,8))
plt.hist(high_part['act_composite_19'],color='r',alpha=.5,label="High Particpiation");
plt.hist(low_part['act_composite_19'],color='b',alpha=.5,label="Low Participation");

plt.title('2019 ACT Scores for High / Low Participation',fontsize=20)
plt.figtext(.5, 0.01," Interpretation: The above image shows a side by side comparison of test scores for states with both high and low level of ACT participation in 2019. \n *High participation >= 70% / Low participation < 30%", wrap=True,verticalalignment='center_baseline', horizontalalignment='center', fontsize=12)
plt.legend();
plt.savefig("../images/2019_ACT_High_Low_hist.png")

# %%
# It looks like states with higher rate of participation actually have lower scores....
high_part = df_act_sat_combined[df_act_sat_combined['sat_participation_19'] >= .7]

low_part = df_act_sat_combined[df_act_sat_combined['sat_participation_19'] < .3]
plt.subplots(figsize=(10,8))
plt.hist(high_part['sat_total_19'],color='y',alpha=.5,label="High Particpiation");
plt.hist(low_part['sat_total_19'],color='g',alpha=.5,label="Low Participation");

plt.title('2019 SAT Scores for High / Low Participation',fontsize=20)
plt.figtext(.5, 0.01," Interpretation: The above image shows a side by side comparison of test scores for states with both high and low level of SAT participation in 2019. \n *High participation >= 70% / Low participation < 30%", wrap=True,verticalalignment='center_baseline', horizontalalignment='center', fontsize=12)
plt.legend();
plt.savefig("../images/2019_SAT_High_Low_hist.png")

# %%
fig,ax = plt.subplots(figsize=(10,8))

plt.title('2017 ACT/SAT Scores Compared to Participation',fontsize=20)
ax.scatter(df_act_sat_combined['sat_participation_17'],df_act_sat_combined['sat_total_17'], color='salmon', alpha=.4, s=200)
ax.set_xlabel("Participation",fontsize=14,)
ax.set_ylabel("2017 SAT Score",fontsize=14, color='salmon')

ax2=ax.twinx()
ax2.scatter(df_act_sat_combined['act_participation_17'],df_act_sat_combined['act_composite_17'], alpha=.4, s=200)
ax2.set_ylabel("2017 ACT Score",fontsize=14,color='#1f77b4')


plt.figtext(0.5, 0.01," Interpretation: The above image shows that for both the ACT (blue) and SAT (salmon), as participation increases, scores tend to drop. The trend does appear to be stronger for ACT scores.", wrap=True, horizontalalignment='center', fontsize=12)
plt.show()

plt.savefig("../images/2017_ACT_SAT_scatter.jpg")

# %%
fig,ax = plt.subplots(figsize=(10,8))

plt.title('2018 ACT/SAT Scores Compared to Participation',fontsize=20)
ax.scatter(df_act_sat_combined['sat_participation_18'],df_act_sat_combined['sat_total_18'], color='salmon', alpha=.4, s=200)
ax.set_xlabel("Participation",fontsize=14,)
ax.set_ylabel("2018 SAT Score",fontsize=14, color='salmon')

ax2=ax.twinx()
ax2.scatter(df_act_sat_combined['act_participation_18'],df_act_sat_combined['act_composite_18'], alpha=.4, s=200)
ax2.set_ylabel("2018 ACT Score",fontsize=14,color='#1f77b4')

plt.figtext(0.5, 0.01," Interpretation: The above image shows that for both the ACT (blue) and SAT (salmon), as participation increases, scores tend to drop.The trend does appear to be stronger for ACT scores.", wrap=True, horizontalalignment='center', fontsize=12)
plt.show()
plt.savefig("../images/2018_ACT_SAT_scatter.png")

# %%
fig,ax = plt.subplots(figsize=(10,8))

plt.title('2019 ACT/SAT Scores Compared to Participation',fontsize=20)
ax.scatter(df_act_sat_combined['sat_participation_19'],df_act_sat_combined['sat_total_19'], color='salmon', alpha=.4, s=200)
ax.set_xlabel("Participation",fontsize=14,)
ax.set_ylabel("2019 SAT Score",fontsize=14, color='salmon')

ax2=ax.twinx()
ax2.scatter(df_act_sat_combined['act_participation_19'],df_act_sat_combined['act_composite_19'], alpha=.4, s=200)
ax2.set_ylabel("2019 ACT Score",fontsize=14,color='#1f77b4')

plt.figtext(0.5, 0.01," Interpretation: The above image shows that for both the ACT (blue) and SAT (salmon), as participation increases, scores tend to drop.The trend does appear to be stronger for ACT scores.", wrap=True, horizontalalignment='center', fontsize=12)
plt.show()
plt.savefig("../images/2019_ACT_SAT_scatter.png")

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **Conclusions and Recommendations:** *It appears as though there is definitely a corelatipon between ACT/SAT exam participation and the average scores at the state level.  When trying to compare the effectiveness of one state education program to another, using the average ACT or SAT score would not be recommended as a fair barrometer.*

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
